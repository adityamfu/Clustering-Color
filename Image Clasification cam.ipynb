# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import webcolors
from webcolors import name_to_rgb, rgb_to_name
matplotlib.use('TkAgg')

import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# Load a model
model = YOLO('yolov8n.pt')

def find_closest_color_name(r, g, b):
    target_rgb = (r, g, b)

    def rgb_to_lab(rgb):
        # Convert RGB to CIE Lab color space
        r, g, b = [x / 255.0 for x in rgb]
        r = ((r + 0.055) / 1.055) ** 2.4 if (r > 0.04045) else (r / 12.92)
        g = ((g + 0.055) / 1.055) ** 2.4 if (g > 0.04045) else (g / 12.92)
        b = ((b + 0.055) / 1.055) ** 2.4 if (b > 0.04045) else (b / 12.92)

        r, g, b = [x * 100.0 for x in [r, g, b]]
        x = r * 0.4124564 + g * 0.3575761 + b * 0.1804375
        y = r * 0.2126729 + g * 0.7151522 + b * 0.0721750
        z = r * 0.0193339 + g * 0.1191920 + b * 0.9503041

        x = x / 95.047
        y = y / 100.000
        z = z / 108.883

        x = (x ** (1.0 / 3.0)) if (x > 0.008856) else (903.3 * x + 16.0) / 116.0
        y = (y ** (1.0 / 3.0)) if (y > 0.008856) else (903.3 * y + 16.0) / 116.0
        z = (z ** (1.0 / 3.0)) if (z > 0.008856) else (903.3 * z + 16.0) / 116.0

        l = max(0.0, (116.0 * y) - 16.0)
        a = (x - y) * 500.0
        b = (y - z) * 200.0

        return l, a, b

    def delta_e_cie76(color1, color2):
        # Calculate the color difference using CIE76 formula
        l1, a1, b1 = color1
        l2, a2, b2 = color2
        delta_l = l2 - l1
        delta_a = a2 - a1
        delta_b = b2 - b1
        return (delta_l ** 2 + delta_a ** 2 + delta_b ** 2) ** 0.5

    # Get the names and RGB values of all valid CSS3 colors
    all_color_data = [(name.lower(), webcolors.name_to_rgb(name)) for name in webcolors.CSS3_NAMES_TO_HEX]

    # Find the closest color name
    closest_color_name = min(all_color_data, key=lambda data: delta_e_cie76(rgb_to_lab(target_rgb), rgb_to_lab(data[1])))[0]

    return closest_color_name

cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

while True:
    ret, img= cap.read()
    if cv2.waitKey(1) == ord('q'):
        break

    results = model(img)

    # make img color more saturated
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    hsv[..., 1] = hsv[..., 1] * 1.5
    img = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)

    for r in results:

        detection_count = r.boxes.shape[0]

        name = []
        for detection in range(detection_count):
            cls = int(r.boxes.cls[detection].item())
            name.append(r.names[cls])

        boxes = r.boxes.xyxy.numpy()
        color_list = []
        for i in range(len(boxes)):
            x1 = int(boxes[i][0])
            y1 = int(boxes[i][1])
            x2 = int(boxes[i][2])
            y2 = int(boxes[i][3])

            # get average color of bounding box
            average_color = np.mean(img[y1:y2, x1:x2], axis=(0, 1))
            # convert back to integer color
            average_color = [int(c) for c in average_color]
            # add average color to list
            color_list.append(average_color)

        # draw bounding boxes and labels of detections with color of average color of bounding box
        for i in range(len(boxes)):
            x1 = int(boxes[i][0])
            y1 = int(boxes[i][1])
            x2 = int(boxes[i][2])
            y2 = int(boxes[i][3])

            # draw bounding box with weight relative to img size
            cv2.rectangle(img, (x1, y1), (x2, y2), color_list[i], int(img.shape[0] / 100) + 1)

            # make label text size proportional to img size
            label_size = (img.shape[0] / 1000) * 1.5

            # draw background rectangle for label text make width proportional to name length
            (label_width, label_height), baseline = cv2.getTextSize(name[i], cv2.FONT_HERSHEY_SIMPLEX, label_size, 2)
            cv2.rectangle(img, (x1, y1), (x1 + label_width, y1 + int(label_size * 20)), color_list[i], -1)

            # draw label text
            cv2.putText(img, name[i], (x1, y1 + int(label_size * 20)), cv2.FONT_HERSHEY_SIMPLEX, label_size,
                        (255, 255, 255), 2)

            # in next row draw color name with background rectangle of color with function find_closest_color_name() add little gap between rows
            (label_width, label_height), baseline = cv2.getTextSize(find_closest_color_name(color_list[i][0], color_list[i][1], color_list[i][2]), cv2.FONT_HERSHEY_SIMPLEX, label_size, 2)
            cv2.rectangle(img, (x1, y1 + int(label_size * 20) + int(label_size * 20)), (x1 + label_width, y1 + int(label_size * 20) + int(label_size * 20) + int(label_size * 20)), color_list[i], -1)

            # draw color name
            cv2.putText(img, find_closest_color_name(color_list[i][0], color_list[i][1], color_list[i][2]), (x1, y1 + int(label_size * 20) + int(label_size * 20) + int(label_size * 20)), cv2.FONT_HERSHEY_SIMPLEX, label_size,
                        (255, 255, 255), 2)

    cv2.imshow('Webcam', img)




cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 262.3ms
# Speed: 6.0ms preprocess, 262.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 272.3ms
# Speed: 10.0ms preprocess, 272.3ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 337.1ms
# Speed: 5.0ms preprocess, 337.1ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 328.1ms
# Speed: 6.0ms preprocess, 328.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 232.4ms
# Speed: 4.0ms preprocess, 232.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 224.4ms
# Speed: 3.0ms preprocess, 224.4ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 banana, 198.5ms
# Speed: 4.0ms preprocess, 198.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 banana, 1 hot dog, 217.4ms
# Speed: 3.0ms preprocess, 217.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 197.5ms
# Speed: 3.0ms preprocess, 197.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 219.4ms
# Speed: 3.0ms preprocess, 219.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 232.4ms
# Speed: 3.0ms preprocess, 232.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 206.4ms
# Speed: 3.0ms preprocess, 206.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 203.5ms
# Speed: 3.0ms preprocess, 203.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 227.4ms
# Speed: 4.0ms preprocess, 227.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 206.4ms
# Speed: 5.0ms preprocess, 206.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 194.5ms
# Speed: 4.0ms preprocess, 194.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 290.2ms
# Speed: 4.0ms preprocess, 290.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 211.4ms
# Speed: 3.0ms preprocess, 211.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.4ms
# Speed: 3.0ms preprocess, 212.4ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 219.4ms
# Speed: 4.0ms preprocess, 219.4ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 216.4ms
# Speed: 2.0ms preprocess, 216.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 229.4ms
# Speed: 4.0ms preprocess, 229.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 221.4ms
# Speed: 3.0ms preprocess, 221.4ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 216.4ms
# Speed: 4.0ms preprocess, 216.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.4ms
# Speed: 4.0ms preprocess, 207.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 215.4ms
# Speed: 6.0ms preprocess, 215.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 1 cell phone, 226.4ms
# Speed: 4.0ms preprocess, 226.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 remote, 1 cell phone, 208.4ms
# Speed: 4.0ms preprocess, 208.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote,
5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 218.4ms
# Speed: 3.0ms preprocess, 218.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 221.4ms
# Speed: 4.0ms preprocess, 221.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 290.2ms
# Speed: 29.9ms preprocess, 290.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 200.5ms
# Speed: 6.0ms preprocess, 200.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 207.4ms
# Speed: 3.0ms preprocess, 207.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 212.4ms
# Speed: 3.0ms preprocess, 212.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 218.4ms
# Speed: 4.0ms preprocess, 218.4ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 215.4ms
# Speed: 4.0ms preprocess, 215.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 214.4ms
# Speed: 3.0ms preprocess, 214.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.4ms
# Speed: 5.0ms preprocess, 210.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 220.4ms
# Speed: 5.0ms preprocess, 220.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.5ms
# Speed: 4.0ms preprocess, 203.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 205.4ms
# Speed: 5.0ms preprocess, 205.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 215.4ms
# Speed: 4.0ms preprocess, 215.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 210.4ms
# Speed: 4.0ms preprocess, 210.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 212.4ms
# Speed: 5.0ms preprocess, 212.4ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 190.5ms
# Speed: 4.0ms preprocess, 190.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 225.4ms
# Speed: 6.0ms preprocess, 225.4ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 220.4ms
# Speed: 3.0ms preprocess, 220.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 212.4ms
# Speed: 4.0ms preprocess, 212.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 199.5ms
# Speed: 4.0ms preprocess, 199.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.4ms
# Speed: 4.0ms preprocess, 210.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.4ms
# Speed: 3.0ms preprocess, 209.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 304.2ms
# Speed: 4.0ms preprocess, 304.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 231.4ms
# Speed: 3.0ms preprocess, 231.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 214.4ms
# Speed: 4.0ms preprocess, 214.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 216.4ms
# Speed: 4.0ms preprocess, 216.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 214.4ms
# Speed: 5.0ms preprocess, 214.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.4ms
# Speed: 3.0ms preprocess, 210.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 baseball bat, 203.5ms
# Speed: 3.0ms preprocess, 203.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 212.4ms
# Speed: 3.0ms preprocess, 212.4ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 215.4ms
# Speed: 3.0ms preprocess, 215.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 215.4ms
# Speed: 3.0ms preprocess, 215.4ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 207.4ms
# Speed: 3.0ms preprocess, 207.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cow, 214.4ms
# Speed: 3.0ms preprocess, 214.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bird, 1 baseball bat, 207.4ms
# Speed: 5.0ms preprocess, 207.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cow, 1 baseball bat, 208.4ms
# Speed: 3.0ms preprocess, 208.4ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 baseball bat, 219.4ms
# Speed: 4.0ms preprocess, 219.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bird, 1 baseball bat, 198.5ms
# Speed: 3.0ms preprocess, 198.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 194.5ms
# Speed: 5.0ms preprocess, 194.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 baseball bat, 200.5ms
# Speed: 5.0ms preprocess, 200.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 217.4ms
# Speed: 4.0ms preprocess, 217.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 baseball bat, 211.4ms
# Speed: 4.0ms preprocess, 211.4ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 suitcase, 1 baseball bat, 226.4ms
# Speed: 3.0ms preprocess, 226.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 302.2ms
# Speed: 3.0ms preprocess, 302.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 suitcase, 1 surfboard, 195.5ms
# Speed: 5.0ms preprocess, 195.5ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 205.4ms
# Speed: 3.0ms preprocess, 205.4ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 baseball bat, 1 surfboard, 230.4ms
# Speed: 5.0ms preprocess, 230.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 suitcase, 1 baseball bat, 197.5ms
# Speed: 3.0ms preprocess, 197.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 baseball bat, 203.5ms
# Speed: 5.0ms preprocess, 203.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 baseball bat, 200.5ms
# Speed: 3.0ms preprocess, 200.5ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 baseball bat, 220.4ms
# Speed: 4.0ms preprocess, 220.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 195.5ms
# Speed: 4.0ms preprocess, 195.5ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 224.4ms
# Speed: 5.0ms preprocess, 224.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 214.4ms
# Speed: 23.9ms preprocess, 214.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 210.4ms
# Speed: 4.0ms preprocess, 210.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 193.5ms
# Speed: 5.0ms preprocess, 193.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 223.4ms
# Speed: 6.0ms preprocess, 223.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 207.4ms
# Speed: 7.0ms preprocess, 207.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 205.4ms
# Speed: 4.0ms preprocess, 205.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 222.4ms
# Speed: 3.0ms preprocess, 222.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 199.5ms
# Speed: 4.0ms preprocess, 199.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 225.4ms
# Speed: 4.0ms preprocess, 225.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202